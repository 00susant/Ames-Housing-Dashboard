# %%
#!pip install jupyter_dash
# Out:
# Requirement already satisfied: jupyter_dash in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (0.4.0)
# Requirement already satisfied: retrying in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: ipython in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from jupyter_dash) (7.21.0)
# Requirement already satisfied: ansi2html in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from jupyter_dash) (1.6.0)
# Requirement already satisfied: dash in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from jupyter_dash) (1.20.0)
# Requirement already satisfied: ipykernel in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from jupyter_dash) (5.5.0)
# Requirement already satisfied: flask in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: requests in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from jupyter_dash) (2.22.0)
# Requirement already satisfied: dash-core-components==1.16.0 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from dash->jupyter_dash) (1.16.0)
# Requirement already satisfied: future in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: flask in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: flask-compress in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: dash-renderer==1.9.1 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from dash->jupyter_dash) (1.9.1)
# Requirement already satisfied: dash-table==4.11.3 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from dash->jupyter_dash) (4.11.3)
# Requirement already satisfied: plotly in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from dash->jupyter_dash) (4.14.3)
# Requirement already satisfied: dash-html-components==1.1.3 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from dash->jupyter_dash) (1.1.3)
# Requirement already satisfied: click>=5.1 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from flask->jupyter_dash) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from flask->jupyter_dash) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from flask->jupyter_dash) (2.10.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from flask->jupyter_dash) (0.15.5)
# Requirement already satisfied: flask in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: brotli in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: tornado>=4.2 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: jupyter-client in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from ipykernel->jupyter_dash) (5.0.5)
# Requirement already satisfied: ipython in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from jupyter_dash) (7.21.0)
# Requirement already satisfied: backcall in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from ipython->jupyter_dash) (42.0.1)
# Requirement already satisfied: colorama in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from ipython->jupyter_dash) (0.4.3)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from ipykernel->jupyter_dash) (5.0.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from ipython->jupyter_dash) (0.18.0)
# Requirement already satisfied: pygments in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from ipython->jupyter_dash) (2.4.2)
# Requirement already satisfied: pickleshare in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from ipython->jupyter_dash) (2.0.10)
# Requirement already satisfied: decorator in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from ipython->jupyter_dash) (4.4.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (1.1.1)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from ipykernel->jupyter_dash) (5.0.5)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (22.0.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (4.7.1)
# Requirement already satisfied: tornado>=4.2 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from ipykernel->jupyter_dash) (5.0.5)
# Requirement already satisfied: pywin32>=1.0 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter_dash) (227)
# Requirement already satisfied: six in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from plotly->dash->jupyter_dash) (1.14.0)
# Requirement already satisfied: retrying in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: wcwidth in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: six in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from plotly->dash->jupyter_dash) (1.14.0)
# Requirement already satisfied: six in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from plotly->dash->jupyter_dash) (1.14.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from requests->jupyter_dash) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from requests->jupyter_dash) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from requests->jupyter_dash) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from requests->jupyter_dash) (1.24.3)
# Requirement already satisfied: six in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from plotly->dash->jupyter_dash) (1.14.0)
# Requirement already satisfied: ipython-genutils in c:\users\susant\appdata\local\programs\python\python37\lib\site-packages (from traitlets>=4.1.0->ipykernel->jupyter_dash) (0.2.0)
# WARNING: You are using pip version 20.3.1; however, version 21.1 is available.
# You should consider upgrading via the 'c:\users\susant\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import plotly
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output, State
from jupyter_dash import JupyterDash
import plotly.express as px

# %%
df = pd.read_csv('clean_v3.csv')
#df.head()
# Out:
#    LotArea  OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0     8450            7       2003          2003       196.0         706
# 1     9600            6       1976          1976         0.0         978
# 2    11250            7       2001          2002       162.0         486
# 3     9550            7       1915          1970         0.0         216
# 4    14260            8       2000          2000       350.0         655
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  ...  GarageArea  WoodDeckSF  \
# 0          856       856       854       1710  ...         548           0
# 1         1262      1262         0       1262  ...         460         298
# 2          920       920       866       1786  ...         608           0
# 3          756       961       756       1717  ...         642           0
# 4         1145      1145      1053       2198  ...         836         192
#
#    OpenPorchSF  SalePrice  MasVnrType  ExterQual  BsmtQual  KitchenQual  \
# 0           61     208500     BrkFace         Gd        Gd           Gd
# 1            0     181500        None         TA        Gd           TA
# 2           42     223500     BrkFace         Gd        Gd           Gd
# 3           35     140000        None         TA        TA           Gd
# 4           84     250000     BrkFace         Gd        Gd           Gd
#
#    GarageFinish SalePrice.1
# 0           RFn      208500
# 1           RFn      181500
# 2           RFn      223500
# 3           Unf      140000
# 4           RFn      250000
#
# [5 rows x 25 columns]

# %%
df.drop('SalePrice.1', inplace  = True, axis = 1)
#df.head()
# Out:
#    LotArea  OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0     8450            7       2003          2003       196.0         706
# 1     9600            6       1976          1976         0.0         978
# 2    11250            7       2001          2002       162.0         486
# 3     9550            7       1915          1970         0.0         216
# 4    14260            8       2000          2000       350.0         655
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  ...  GarageCars  GarageArea  \
# 0          856       856       854       1710  ...           2         548
# 1         1262      1262         0       1262  ...           2         460
# 2          920       920       866       1786  ...           2         608
# 3          756       961       756       1717  ...           3         642
# 4         1145      1145      1053       2198  ...           3         836
#
#    WoodDeckSF  OpenPorchSF  SalePrice  MasVnrType  ExterQual  BsmtQual  \
# 0           0           61     208500     BrkFace         Gd        Gd
# 1         298            0     181500        None         TA        Gd
# 2           0           42     223500     BrkFace         Gd        Gd
# 3           0           35     140000        None         TA        TA
# 4         192           84     250000     BrkFace         Gd        Gd
#
#    KitchenQual GarageFinish
# 0           Gd          RFn
# 1           TA          RFn
# 2           Gd          RFn
# 3           Gd          Unf
# 4           Gd          RFn
#
# [5 rows x 24 columns]

# %%
# Create a dash application
app = JupyterDash(__name__)
JupyterDash.infer_jupyter_proxy_config()
#JupyterDash.infer_jupyter_proxy_config()

app.layout = html.Div(children = [
    # Title
    html.H1('Ames Housing Dashboard',
            style = {'textAlign': 'center','color' : '#503D36','font-size': '40px'}),
    
    
    html.Div(['Input Year: ', dcc.Input(id = 'input-year', value = 2010, type ='number', style = {'height':'35px', 'font-size': 25})], style={'font-size': 30}),
    
    html.Br(),
    
    html.Div([html.Div(dcc.Graph(id = 'YearBuilt')), html.Div(dcc.Graph(id = 'OverallQual'))], style = {'display': 'flex'}),
    html.Br(),
    html.Div([html.Div(dcc.Graph(id = 'FullBath')), html.Div(dcc.Graph(id = 'Fireplaces'))], style = {'display': 'flex'}),
    html.Br(),
    html.Div(dcc.Graph(id = 'TotRmsAbvGrd'), style={'width':'65%'})
])

@app.callback(
    [Output(component_id = 'YearBuilt', component_property = 'figure'),
     Output(component_id = 'OverallQual', component_property = 'figure'),
     Output(component_id = 'FullBath', component_property = 'figure'),
     Output(component_id = 'Fireplaces', component_property = 'figure'),
     Output(component_id = 'TotRmsAbvGrd', component_property = 'figure'),
    ],
    Input(component_id = 'input-year', component_property = 'value')
)

def get_graph(test):
    df_yb = df.groupby('YearBuilt').mean().reset_index()
    YearBuilt = px.line(df_yb, x = 'YearBuilt', y = 'SalePrice')
    
    #df_oq = df.groupby('YearBuilt').mean().reset_index()
    OverallQual = px.line(df_yb, x = 'YearBuilt', y = 'OverallQual')
    
    df_fb = df.groupby('FullBath').mean().reset_index()
    FullBath = px.bar(df_fb, x = 'FullBath', y = 'SalePrice')
    
    df_fp = df.groupby('Fireplaces').mean().reset_index()
    Fireplaces = px.bar(df_fp, x = 'Fireplaces', y = 'SalePrice')
    
    df_trag = df.groupby('TotRmsAbvGrd').mean().reset_index()
    TotRmsAbvGrd = px.bar(df_trag, x = 'TotRmsAbvGrd', y = 'SalePrice')
    
    return[YearBuilt, OverallQual, FullBath, Fireplaces, TotRmsAbvGrd]

if __name__ == '__main__':
    app.run_server(mode="external", host="localhost", port=7645, debug=True)
# Out:
# Dash app running on http://localhost:7645/
